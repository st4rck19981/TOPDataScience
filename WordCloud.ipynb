# %%
#Agregar encabezado
import pandas as pd
df=pd.read_csv('train.csv', engine='python')
df.columns=['class','id','datetime','query','name','content']
df.to_csv('train2.csv')
#en la 1ra fila se agrego una coma, hay q eliminarla

# %%
#Dividir archivo por clases
df = pd.read_csv('train.csv', engine='python')
df.columns=['class','id','datetime','query','name','content']
df=df[df['class']==4]
df.to_csv('negativo.csv')

# %%
#Separar la dataset y convertir a excel
df = pd.read_csv('train.csv', engine='python')
df.columns=['class','id','datetime','query','name','content']
dfPOS=df[df['class']==0]
dfNEG=df[df['class']==4]
dfPOS.to_excel('positivo.xlsx')
dfNEG.to_excel('negativo.xlsx')

# %%
print(df['content'][0],";",df['content'][1])
# Out:
# I LOVE @Health4UandPets u guys r the best!!  ; im meeting up with one of my besties tonight! Cant wait!!  - GIRL TALK!!

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#-----WORDCLOUD------

import pandas as pd
data=pd.read_csv('negativo.csv',encoding='utf-8')
data.head()
# Out:
#    Unnamed: 0  class          id                      datetime     query  \
# 0      799999      4  1467822272  Mon Apr 06 22:22:45 PDT 2009  NO_QUERY
# 1      800000      4  1467822273  Mon Apr 06 22:22:45 PDT 2009  NO_QUERY
# 2      800001      4  1467822283  Mon Apr 06 22:22:46 PDT 2009  NO_QUERY
# 3      800002      4  1467822287  Mon Apr 06 22:22:46 PDT 2009  NO_QUERY
# 4      800003      4  1467822293  Mon Apr 06 22:22:46 PDT 2009  NO_QUERY
#
#           name                                            content
# 0        ersle       I LOVE @Health4UandPets u guys r the best!!
# 1     becca210  im meeting up with one of my besties tonight! ...
# 2    Wingman29  @DaRealSunisaKim Thanks for the Twitter add, S...
# 3    katarinka  Being sick can be really cheap when it hurts t...
# 4  _EmilyYoung    @LovesBrooklyn2 he has that effect on everyone

# %%
data.shape
# Out:
# (799999, 7)

# %%
import unidecode
import pickle
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import numpy as np
from PIL import Image
import random
from palettable.colorbrewer.sequential import Reds_9
from palettable.cmocean.diverging import Balance_20
from palettable.tableau import BlueRed_12
#from scipy.misc import imread

def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Balance_20.colors[random.randint(2,18)])

# %%
sw=set(STOPWORDS)
print(len(sw))
# Out:
# 192

# %%
#Agregar nuevas stopwords
sw.add('https')

# %%
textos=' '.join(data.fillna('')['content'].tolist())
len(textos)
# Out:
# 59902745

# %%
for i in range (100,150):
    print(textos[i])
# Out:
# a
# l
# s
# o
# .
#
# B
# l
# a
# h
# !
#
# @
# K
# e
# n
# i
# c
# h
# a
# n
#
# I
#
# d
# i
# v
# e
# d
#
# m
# a
# n
# y
#
# t
# i
# m
# e
# s
#
# f
# o
# r
#
# t
# h
# e
#
# b

# %%
#GENERADOR DEL WORD CLOUD
wc = WordCloud(
    background_color="rgba(255,255,255,0)",mode="RGBA",
    width=1800,
    height=1400,
    stopwords=[]
).generate(textos)

wc.recolor(color_func=color_func, random_state=5)
print("LISTO!!")
# Out:
# LISTO!!

# %%
# %matplotlib notebook
plt.imshow(wc)
plt.axis('off')
plt.savefig('./X.png',dpi=600)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#analizar aquellos textos que contengan ciertas palabras clave
textos=' '.join(data[data.content.str.contains('work')].fillna('')['content'].tolist())

# %%
# SENTIMENT ANALISIS

# %%
#see
